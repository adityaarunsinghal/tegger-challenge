# %%
# !pip install pickle5
import matplotlib.pyplot as plt
import pandas as pd
import re
# import pickle5 as pickle
import seaborn as sns

sns.set(rc={'figure.figsize':(22,11)})

# %%
topics = pd.read_csv("./topics.csv").iloc[:,1:]

# %%
topics.sort_values(by='theme', inplace=True)
topics.set_index('theme', inplace=True)

# %%
topics
# Out:
#           argentina  australia  brazil  canada  ...  turkey  uk  america  eu
# theme                                           ...
# business          0          0       1       0  ...       0   1        0   0
# business          1          1       0       1  ...       0   0        1   1
# business          0          0       0       0  ...       1   0        0   0
# business          1          1       0       1  ...       0   0        0   0
# business          1          1       0       1  ...       0   1        1   1
# ...             ...        ...     ...     ...  ...     ...  ..      ...  ..
# tech              0          0       0       0  ...       1   0        0   1
# tech              0          1       0       0  ...       0   0        0   0
# tech              1          1       0       1  ...       0   0        1   0
# tech              1          1       0       1  ...       0   1        1   1
# ...

# %%
df_sum = topics.sum(numeric_only=True)

# %%
df_sum.plot.bar()

# %%
# plt.Figure(figsize=(30,20))
sns.heatmap(topics.T)
plt.show()
